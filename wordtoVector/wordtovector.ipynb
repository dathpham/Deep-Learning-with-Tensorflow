# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'as', 'of', 'originated', 'term']

# %%
data_index = 0
from itertools import compress
def generate_bagbatch(batch_size, bag_window):
  global data_index
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * bag_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = bag_window  # target label at the center of the buffer
    targets_to_avoid = [ bag_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
    targets_to_avoid.append(target)
#     mask = [1] * span
#     mask[bag_window] = 0 
    batch[i] = buffer[bag_window]
    labels[i, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for  bag_window in [1,2]:
    data_index = 0
    batch, labels = generate_bagbatch(batch_size=8, bag_window=bag_window)
    print('\n skip_window = %d:' %  bag_window)
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
#  skip_window = 1:
#     batch: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#     labels: ['as', 'a', 'as', 'a', 'abuse', 'first', 'used', 'first']
#
#  skip_window = 2:
#     batch: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#     labels: ['originated', 'term', 'a', 'first', 'term', 'against', 'against', 'first']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_bagbatch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.566727
# Nearest to th: gloucester, seamlessly, gylfaginning, determining, depot, shamanism, cio, parcel,
# Nearest to is: recognize, hedonism, dumb, barbagia, dw, cysteine, tracy, oxidize,
# Nearest to new: stockpiles, klamath, solstices, webmaster, steward, handbook, shank, milah,
# Nearest to however: singularly, unverified, dago, submitting, inaccurately, hort, giraffe, woollen,
# Nearest to this: impractical, mistress, repel, zealot, harding, deconstruction, publication, schwarzschild,
# Nearest to two: yi, asdb, competitive, nou, xa, hammering, princely, immigrants,
# Nearest to zero: lymphocytes, tektites, opiates, megabyte, aelius, workplace, feldman, omphale,
# Nearest to of: digs, abugidas, deems, rodgers, minimal, federico, solely, careers,
# Nearest to the: erection, subsidies, varieties, og, vent, panda, racism, samarkand,
# Nearest to in: hadley, octane, entertainer, nashwaak, sumner, boycott, interchange, nutritious,
# Nearest to years: shire, interplay, ashford, expenditures, grays, nassau, candy, foiled,
# Nearest to these: phodopus, inspecting, indo, stanislaw, kiwi, makarios, annihilated, aspects,
# Nearest to d: hath, doreen, stink, popularised, corruptions, runnymede, slavs, members,
# Nearest to first: alright, deconstruction, emphasizing, directives, empowerment, airplanes, routinely, willy,
# Nearest to more: worthies, underdogs, baptists, adele, vita, quarrels, pontius, fluoxetine,
# Nearest to only: deals, liv, dunham, hyman, metrizable, terraces, tractor, surge,
# Average loss at step 2000: 4.432153
# Average loss at step 4000: 3.955981
# Average loss at step 6000: 3.796454
# Average loss at step 8000: 3.671284
# Average loss at step 10000: 3.644453
# Nearest to th: ferrell, eight, cio, listing, freight, determining, ranging, seamlessly,
# Nearest to is: was, are, has, marginalism, does, chapel, were, ceo,
# Nearest to new: warmly, flurry, philharmonic, reclaim, stockpiles, through, webmaster, iterating,
# Nearest to however: altruists, tidings, dago, forces, reorganization, singularly, cooker, so,
# Nearest to this: the, it, which, exerting, a, his, their, he,
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to zero: five, three, six, four, nine, eight, seven, two,
# Nearest to of: in, for, same, and, towards, at, after, primed,
# Nearest to the: its, his, this, a, their, s, intuitively, each,
# Nearest to in: on, from, at, for, between, of, with, nashwaak,
# Nearest to years: hess, wicked, sayer, userland, expenditures, operatic, patois, grays,
# Nearest to these: inspecting, unleashing, pathos, nicolae, aspects, supper, its, unaids,
# Nearest to d: b, hath, tallinn, runnymede, harlem, copper, mapsto, cimmerians,
# Nearest to first: directives, output, emphasizing, crematorium, yr, drain, alright, australopithecines,
# Nearest to more: baptists, centum, austroasiatic, weary, underdogs, implementation, estimated, ncc,
# Nearest to only: hyman, branding, amaranthus, cot, bras, incumbent, metrizable, chicks,
# Average loss at step 12000: 3.671867
# Average loss at step 14000: 3.638753
# Average loss at step 16000: 3.658192
# Average loss at step 18000: 3.634643
# Average loss at step 20000: 3.530408
# Nearest to th: six, eight, listing, ferrell, minnesotans, freight, determining, five,
# Nearest to is: was, has, are, be, became, were, in, by,
# Nearest to new: flurry, warmly, million, ucd, milah, stockpiles, reclaim, sept,
# Nearest to however: but, so, initiating, tidings, mend, dago, hort, nearly,
# Nearest to this: it, which, the, believer, a, exerting, that, bicarbonate,
# Nearest to two: three, five, eight, six, seven, one, four, zero,
# Nearest to zero: eight, seven, five, six, four, nine, three, two,
# Nearest to of: in, same, from, quest, for, copra, towards, whole,
# Nearest to the: a, this, their, its, his, analytic, each, them,
# Nearest to in: on, at, during, within, of, is, nashwaak, between,
# Nearest to years: operatic, wicked, userland, expenditures, bandmates, months, five, asymptomatic,
# Nearest to these: some, they, inspecting, many, such, unleashing, canopus, stanislaw,
# Nearest to d: b, hath, harlem, j, tallinn, flowing, cobalt, rosario,
# Nearest to first: directives, yr, airplanes, chest, resort, last, fondness, drain,
# Nearest to more: less, most, very, centum, coconuts, austroasiatic, estimated, ecoregion,
# Nearest to only: hyman, cot, bras, amaranthus, branding, it, chicks, epicureanism,
# Average loss at step 22000: 3.588075
# Average loss at step 24000: 3.565984
# Average loss at step 26000: 3.525553
# Average loss at step 28000: 3.565982
# Average loss at step 30000: 3.554197
# Nearest to th: six, five, listing, minnesotans, pounds, four, eight, ferrell,
# Nearest to is: was, are, has, be, became, although, curiae, audit,
# Nearest to new: flurry, warmly, million, demonstration, illustrates, iain, milah, daisy,
# Nearest to however: but, although, so, though, mend, that, unverified, tidings,
# Nearest to this: which, it, the, that, some, shifted, bicarbonate, monomers,
# Nearest to two: three, four, six, eight, five, seven, nine, one,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to of: primed, in, same, carvings, for, from, chimpanzee, triangular,
# Nearest to the: its, their, this, a, some, each, any, many,
# Nearest to in: during, on, at, within, refund, nashwaak, of, from,
# Nearest to years: months, bandmates, wicked, shortwave, operatic, days, asymptomatic, hundred,
# Nearest to these: some, many, such, other, they, are, their, all,
# Nearest to d: b, j, impetuous, cobalt, unorthodox, flowing, harlem, brenner,
# Nearest to first: last, directives, second, yr, drain, resort, barrington, chest,
# Nearest to more: less, very, most, greater, baptists, longer, austroasiatic, weary,
# Nearest to only: hyman, directives, represented, mobs, beanstalk, also, ret, shimon,
# Average loss at step 32000: 3.421419
# Average loss at step 34000: 3.524394
# Average loss at step 36000: 3.510573
# Average loss at step 38000: 3.501082
# Average loss at step 40000: 3.489527
# Nearest to th: six, five, eight, bc, listing, four, minnesotans, pounds,
# Nearest to is: was, has, are, be, gelling, but, persona, makes,
# Nearest to new: flurry, demonstration, ucd, warmly, padre, whig, shadows, illustrates,
# Nearest to however: but, although, though, since, mend, so, unverified, vsl,
# Nearest to this: which, it, the, that, monomers, masquerade, he, loving,
# Nearest to two: three, six, four, five, eight, seven, one, zero,
# Nearest to zero: five, six, eight, four, nine, seven, two, three,
# Nearest to of: including, same, optimal, catchy, chimpanzee, towards, copra, while,
# Nearest to the: their, its, his, each, this, these, some, dumpling,
# Nearest to in: during, within, briefcase, at, from, interchange, between, since,
# Nearest to years: months, days, wicked, times, bandmates, shortwave, hundred, heywood,
# Nearest to these: some, many, such, those, both, their, several, they,
# Nearest to d: b, j, g, cobalt, impetuous, k, harlem, frac,
# Nearest to first: last, second, directives, only, next, yr, same, present,
# Nearest to more: less, most, very, greater, longer, baptists, rather, weary,
# Nearest to only: first, directives, now, still, ret, godavari, actually, also,
# Average loss at step 42000: 3.517959
# Average loss at step 44000: 3.524565
# Average loss at step 46000: 3.493559
# Average loss at step 48000: 3.464212
# Average loss at step 50000: 3.431969
# Nearest to th: listing, four, six, minnesotans, nine, freight, nd, seven,
# Nearest to is: was, has, are, be, makes, compressed, being, although,
# Nearest to new: million, flurry, warmly, ucd, anand, demonstration, whig, milah,
# Nearest to however: but, although, though, while, since, that, and, nor,
# Nearest to this: which, it, the, that, some, there, he, itself,
# Nearest to two: four, three, five, six, eight, seven, nine, one,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to of: in, copra, chimpanzee, including, catchy, respective, abugidas, primed,
# Nearest to the: their, its, this, any, a, his, colliery, squire,
# Nearest to in: during, within, at, of, from, on, between, briefcase,
# Nearest to years: days, months, bandmates, wicked, decades, times, hours, hundred,
# Nearest to these: some, many, several, their, they, those, all, both,
# Nearest to d: b, and, q, j, harlem, impetuous, cobalt, k,
# Nearest to first: last, second, directives, next, yr, laterally, final, present,
# Nearest to more: less, most, very, longer, greater, better, rather, non,
# Nearest to only: directives, not, actually, ret, mise, even, still, represented,
# Average loss at step 52000: 3.468731
# Average loss at step 54000: 3.468910
# Average loss at step 56000: 3.463058
# Average loss at step 58000: 3.391248
# Average loss at step 60000: 3.441301
# Nearest to th: listing, bc, five, minnesotans, nd, migrant, nine, freight,
# Nearest to is: was, has, are, although, callaghan, but, when, be,
# Nearest to new: warmly, demonstration, illustrates, milah, capped, sza, whig, flurry,
# Nearest to however: but, although, that, though, while, when, since, and,
# Nearest to this: which, it, the, itself, any, there, that, another,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to zero: five, four, six, seven, eight, nine, three, two,
# Nearest to of: including, in, and, from, although, copra, catchy, phrased,
# Nearest to the: its, his, their, any, this, a, our, each,
# Nearest to in: during, within, at, on, from, through, until, since,
# Nearest to years: days, months, times, decades, hundred, wicked, minutes, year,
# Nearest to these: many, several, some, both, those, their, all, such,
# Nearest to d: b, j, cobalt, k, q, impetuous, crandall, g,
# Nearest to first: second, last, next, directives, laterally, final, nuit, gentile,
# Nearest to more: less, most, very, greater, longer, rather, annihilated, larger,
# Nearest to only: directives, still, also, traditionally, shimon, now, all, branding,
# Average loss at step 62000: 3.440176
# Average loss at step 64000: 3.399445
# Average loss at step 66000: 3.397219
# Average loss at step 68000: 3.342847
# Average loss at step 70000: 3.386053
# Nearest to th: listing, five, bc, migrant, minnesotans, four, nine, lem,
# Nearest to is: was, has, be, are, does, ramming, became, makes,
# Nearest to new: warmly, special, milah, sza, unleashing, flurry, padre, ucd,
# Nearest to however: but, although, though, while, and, that, encompasses, today,
# Nearest to this: which, it, another, the, that, itself, valdes, some,
# Nearest to two: three, four, one, six, five, seven, eight, zero,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to of: including, in, for, chimpanzee, tanker, optimal, primed, supreme,
# Nearest to the: its, their, a, his, this, each, stretched, squire,
# Nearest to in: during, within, on, under, of, for, from, since,
# Nearest to years: days, months, decades, times, year, minutes, hours, hundred,
# Nearest to these: those, many, several, some, both, various, their, they,
# Nearest to d: b, j, q, cobalt, copper, impetuous, sutherland, residence,
# Nearest to first: last, second, next, directives, third, expertise, fifth, vat,
# Nearest to more: less, very, most, rather, greater, larger, longer, better,
# Nearest to only: directives, least, ret, puebla, either, mise, still, traditionally,
# Average loss at step 72000: 3.423923
# Average loss at step 74000: 3.311008
# Average loss at step 76000: 3.421556
# Average loss at step 78000: 3.441414
# Average loss at step 80000: 3.412741
# Nearest to th: bc, five, four, six, listing, migrant, nd, nine,
# Nearest to is: was, has, are, although, became, makes, becomes, does,
# Nearest to new: flurry, special, sza, ucd, unleashing, metrical, milah, warmly,
# Nearest to however: but, although, though, that, while, when, encompasses, where,
# Nearest to this: which, it, that, another, there, itself, some, ligament,
# Nearest to two: three, four, five, six, one, eight, seven, nine,
# Nearest to zero: five, six, eight, four, seven, nine, three, two,
# Nearest to of: including, chimpanzee, in, for, from, catchy, and, suns,
# Nearest to the: its, their, a, squire, lump, his, our, many,
# Nearest to in: within, during, at, on, throughout, since, under, from,
# Nearest to years: days, months, decades, times, minutes, hours, year, hundred,
# Nearest to these: many, several, those, some, both, all, such, different,
# Nearest to d: b, j, q, cobalt, impetuous, k, g, h,
# Nearest to first: last, second, next, directives, expertise, same, yr, final,
# Nearest to more: less, very, greater, rather, most, larger, better, extremely,
# Nearest to only: directives, either, ret, actually, still, really, traditionally, shimon,
# Average loss at step 82000: 3.341808
# Average loss at step 84000: 3.408936
# Average loss at step 86000: 3.381714
# Average loss at step 88000: 3.402395
# Average loss at step 90000: 3.388103
# Nearest to th: four, six, nine, bc, migrant, eight, five, seven,
# Nearest to is: was, has, are, became, although, does, utr, gives,
# Nearest to new: demonstration, special, flurry, transcendent, galleys, whig, warmly, illustrates,
# Nearest to however: but, although, though, that, while, encompasses, indeed, appears,
# Nearest to this: which, it, another, that, some, the, valdes, there,
# Nearest to two: three, four, five, six, eight, seven, one, zero,
# Nearest to zero: five, seven, four, six, eight, nine, three, two,
# Nearest to of: including, in, conjugate, for, despite, catchy, suns, primed,
# Nearest to the: its, their, his, a, this, any, expeditions, each,
# Nearest to in: during, within, on, throughout, since, among, at, from,
# Nearest to years: days, decades, months, times, year, centuries, hours, minutes,
# Nearest to these: some, many, those, several, such, certain, were, both,
# Nearest to d: b, j, k, cobalt, q, g, c, impetuous,
# Nearest to first: last, second, next, original, fifth, directives, same, third,
# Nearest to more: less, very, most, greater, rather, longer, better, extremely,
# Nearest to only: either, directives, least, until, traditionally, thresholds, approximately, first,
# Average loss at step 92000: 3.337863
# Average loss at step 94000: 3.347823
# Average loss at step 96000: 3.362802
# Average loss at step 98000: 3.076354
# Average loss at step 100000: 3.104390
# Nearest to th: listing, bc, seventeenth, third, nd, twentieth, migrant, six,
# Nearest to is: was, are, became, has, although, be, had, been,
# Nearest to new: demonstration, daimlerchrysler, astray, unleashing, flurry, reclaim, warmly, australasian,
# Nearest to however: but, although, though, that, while, indeed, encompasses, when,
# Nearest to this: which, it, there, another, some, the, what, itself,
# Nearest to two: four, five, three, six, eight, seven, zero, nine,
# Nearest to zero: five, four, eight, nine, six, seven, two, three,
# Nearest to of: in, including, from, newsletters, despite, catchy, following, chimpanzee,
# Nearest to the: his, its, their, our, her, this, unclassified, some,
# Nearest to in: during, at, within, throughout, near, on, among, of,
# Nearest to years: days, months, decades, year, centuries, times, minutes, hours,
# Nearest to these: those, several, many, certain, some, such, both, all,
# Nearest to d: b, sean, orloff, j, impetuous, acf, sutherland, degeneracy,
# Nearest to first: last, second, next, third, final, original, fifth, directives,
# Nearest to more: less, rather, most, very, greater, longer, better, silmarillion,
# Nearest to only: least, until, ret, never, either, traditionally, first, really,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
